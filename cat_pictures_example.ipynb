# %%
pip install pillow matplotlib
# Out:
# Requirement already satisfied: pillow in /Users/aolyu/anaconda3/lib/python3.11/site-packages (9.4.0)
# Requirement already satisfied: matplotlib in /Users/aolyu/anaconda3/lib/python3.11/site-packages (3.7.2)
# Requirement already satisfied: contourpy>=1.0.1 in /Users/aolyu/anaconda3/lib/python3.11/site-packages (from matplotlib) (1.0.5)
# Requirement already satisfied: cycler>=0.10 in /Users/aolyu/anaconda3/lib/python3.11/site-packages (from matplotlib) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/aolyu/anaconda3/lib/python3.11/site-packages (from matplotlib) (4.25.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /Users/aolyu/anaconda3/lib/python3.11/site-packages (from matplotlib) (1.4.4)
# Requirement already satisfied: numpy>=1.20 in /Users/aolyu/anaconda3/lib/python3.11/site-packages (from matplotlib) (1.23.5)
# Requirement already satisfied: packaging>=20.0 in /Users/aolyu/anaconda3/lib/python3.11/site-packages (from matplotlib) (23.1)
# Requirement already satisfied: pyparsing<3.1,>=2.3.1 in /Users/aolyu/anaconda3/lib/python3.11/site-packages (from matplotlib) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/aolyu/anaconda3/lib/python3.11/site-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: six>=1.5 in /Users/aolyu/anaconda3/lib/python3.11/site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import pickle
from PIL import Image
import numpy as np
import matplotlib.pyplot as plt

# Specify the file path
file_path = "/Users/aolyu/Documents/GitHub/nightshade-release/OUTDIR/3.p"

# Load the .p file
with open(file_path, "rb") as file:
    data = pickle.load(file)

# Check the structure of the data
print("Data keys:", data.keys())

# Display the image if it exists
if 'img' in data:
    img_array = data['img']
    img = Image.fromarray(img_array)
    plt.imshow(img)
    plt.title("Image from .p file")
    plt.show()
else:
    print("No image found in the file.")

# Print the text if it exists
if 'text' in data:
    print("Text:", data['text'])
else:
    print("No text found in the file.")
# Out:
# Data keys: dict_keys(['img', 'text'])
# Text: digital drawing caged dog in flooding room art for poem While We Talk
